# %%
from selenium import webdriver
import time
import re
import csv
import string

def isEnglish(s):
    try:
        s.encode('ascii')
    except UnicodeEncodeError:
        return False
    else:
        return True

driver = webdriver.Chrome('C:\webdrivers\chromedriver')
yt_link = input("Link to Youtube video: ")
print("-------------------------------------------------------------------------------------------------------------------")
driver.get(yt_link)
driver.maximize_window()
time.sleep(5)
title = driver.find_element_by_xpath('//*[@id="container"]/h1/yt-formatted-string').text
print("Video Title: " + title)
print("-------------------------------------------------------------------------------------------------------------------")

comment_section = driver.find_element_by_xpath('//*[@id="comments"]')
driver.execute_script("arguments[0].scrollIntoView();", comment_section)
time.sleep(7)

last_height = driver.execute_script("return document.documentElement.scrollHeight")
while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load page
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  
                           u"\U0001F300-\U0001F5FF"
                           u"\U0001F680-\U0001F6FF"
                           u"\U0001F1E0-\U0001F1FF"
                           "]+", flags=re.UNICODE)

name_elems=driver.find_elements_by_xpath('//*[@id="author-text"]')
comment_elems = driver.find_elements_by_xpath('//*[@id="content-text"]')
num_of_names = len(name_elems)
for i in range(num_of_names):
    username = name_elems[i].text    # .replace(",", "|")
    # username = emoji_pattern.sub(r'', username)
    # username = str(username).replace("\n", "---")
    comment = comment_elems[i].text    # .replace(",", "|")
    # comment = emoji_pattern.sub(r'', comment)
    # comment = str(comment).replace("\n", "---")
    
    #if isEnglish(comment) == False:
     #   comment = "NOT ENGLISH"
        
    print(username + ": " + comment) # comment.translate({ord(i):None for i in '' if i not in string.printable})
    print("-------------------------------------------------------------------------------------------------------------------")

driver.close()
# Out:
# Link to Youtube video: https://www.youtube.com/watch?v=LEAKH-cGbs0
# -------------------------------------------------------------------------------------------------------------------
# Video Title: CAPTAIN MARVEL Trailer (4K ULTRA HD) NEW 2019
# -------------------------------------------------------------------------------------------------------------------
# ツ CyBeR ViRuS狂疯: Wow I love it ! 😍😍😍
# -------------------------------------------------------------------------------------------------------------------
# Sagar Koli: This is way more awesome!!!!!
# -------------------------------------------------------------------------------------------------------------------
# Mark de Kok: CAPTANMARVEL.BRIE.LARSON.
# -------------------------------------------------------------------------------------------------------------------
# King Knight: Heart Please
# -------------------------------------------------------------------------------------------------------------------
# Alexis Vince: This trailer is not that good
# Didn't live up to what I thought
# Sorry looks like a green lantern movie
# -------------------------------------------------------------------------------------------------------------------
# Beatriz Guzman: Woooowww
# -------------------------------------------------------------------------------------------------------------------
# 1993 All I HAVE TO DO IS DREAM: She looks badass
# -------------------------------------------------------------------------------------------------------------------
# Spoon: What’s blockbuster
# -------------------------------------------------------------------------------------------------------------------
# Muhammad Ali.p: CAPTAIN AMERICA
# CAPTAIN MARVEL
# 😍😍😍😍😍😍😍😍
# -------------------------------------------------------------------------------------------------------------------
# Rajesh RK: Super wow
# -------------------------------------------------------------------------------------------------------------------
# O.R.T 2002: Yess
# -------------------------------------------------------------------------------------------------------------------
# ProGamer: Captain marvel vs Shazam (Captain marvel)
# -------------------------------------------------------------------------------------------------------------------
# SPIDER MAN GAMER: awsome!!!!!!!!!!!
# -------------------------------------------------------------------------------------------------------------------
# Kokonut GT: Yesss
# -------------------------------------------------------------------------------------------------------------------
# Superheros Comic League: Pa super guys
# -------------------------------------------------------------------------------------------------------------------
# Pokemon gamer The 3th: #marvelstudios
# -------------------------------------------------------------------------------------------------------------------
# Leroson Marshell: FINALLY!!!!!!!!!
# -------------------------------------------------------------------------------------------------------------------
# a person: Did she just punch that old lady?
# -------------------------------------------------------------------------------------------------------------------
# 1993 All I HAVE TO DO IS DREAM: Jude law?
# -------------------------------------------------------------------------------------------------------------------
# Muhammad Ali.p: wt!! is that batman!!
# -------------------------------------------------------------------------------------------------------------------
# Thành Đạt Lê: Yes Finally
# -------------------------------------------------------------------------------------------------------------------
# Shema Kuppusamy: Cool
# -------------------------------------------------------------------------------------------------------------------
# LightZaber Whip: 2nd
# -------------------------------------------------------------------------------------------------------------------
# X 7: In time with great power comes great responsibility 😂-  rip Uncle Ben
# -------------------------------------------------------------------------------------------------------------------
# Swi_ zzle: I didnt get very hype BUT THIS IS AWESOME
# -------------------------------------------------------------------------------------------------------------------
# Akhilesh Surendra: Woahhhoohh
# -------------------------------------------------------------------------------------------------------------------
# Soyab Ghata: 1st i am
# -------------------------------------------------------------------------------------------------------------------
# Angie Natoyn: Looks like a Netflix series
# -------------------------------------------------------------------------------------------------------------------
# Roberto Lodi: 4K????
# -------------------------------------------------------------------------------------------------------------------
# Muhammad Ali.p: CAPTAIN AMERICA
# CAPTAIN MARVEL
# 😍😍😍😍😍😍😍😍
# -------------------------------------------------------------------------------------------------------------------
# sjsjd jejsks: Hehey not bad!!
# -------------------------------------------------------------------------------------------------------------------
# Obsessive Builder: 1St
# -------------------------------------------------------------------------------------------------------------------
# deez nutz: rating is (not bad) this is a disappointing trailer
# -------------------------------------------------------------------------------------------------------------------
# 1993 All I HAVE TO DO IS DREAM: Must watch movie ever
# -------------------------------------------------------------------------------------------------------------------
# Mark de Kok: Leuke.films.van MARVEL.STUDIOS.
# -------------------------------------------------------------------------------------------------------------------
# Sandro: Increíble
# -------------------------------------------------------------------------------------------------------------------
# Joshi Boy: Genial
# -------------------------------------------------------------------------------------------------------------------
# Des The Gamer: sooooo.....
# aquaman in a nutshell?
# -------------------------------------------------------------------------------------------------------------------
# Darius McCaskill: Ayyeee BlockBuster returns 😀
# -------------------------------------------------------------------------------------------------------------------
# Mary Kumar: I love move
# -------------------------------------------------------------------------------------------------------------------
# Nam Khánh Nguyễn: RESPECT UR ELDERS !!!
# -------------------------------------------------------------------------------------------------------------------
# Bratislav Metulski: FAKE AS ALWAYS - JUST UPSCALED
# -------------------------------------------------------------------------------------------------------------------
# Immortal Suspect: just nope
# -------------------------------------------------------------------------------------------------------------------
# Cross Fire: Almost the last Marvel movie maybe released with a timeline before the first Avengers cause Coulson is still alive :p.
#
# Makes sense
# Still fire
# -------------------------------------------------------------------------------------------------------------------
# Talia Prower The Vixen: I'M SO EXCITED 😄😄😄😄😄😄😄😄😄😄😄😄😄😄😄😄😄😄
# -------------------------------------------------------------------------------------------------------------------
# Izzy Shki: Shazam and Aquaman trailers got me hyped.. this one not even close and I'm more of a marvel fan not DC lol. Kinda disappointing.
# -------------------------------------------------------------------------------------------------------------------
# UthacalthingTymbrimi: So 4K UHD video, but crappy mono, out-of-phase audio track?  You're really not very good at this, are you.
# -------------------------------------------------------------------------------------------------------------------
# Brian Yau: very old school
# -------------------------------------------------------------------------------------------------------------------
# topper exam: Captain marvel ka power kiya hai
# -------------------------------------------------------------------------------------------------------------------
# Jalon Tillmon: Yes she is here
# -------------------------------------------------------------------------------------------------------------------
# Daniela Krystal: They brung blockbuster back for a movie !!!! Love that. !
# -------------------------------------------------------------------------------------------------------------------
# Hemant Jangid: 1st
# -------------------------------------------------------------------------------------------------------------------
# Lynden Sterling: Reshoots? I loved it but it could be perfect
# -------------------------------------------------------------------------------------------------------------------
# Raun Smith: When are people going to quit thinking 1440p is 4K?
#  It's not 4K UHD so quit trying to pretend it is.
# -------------------------------------------------------------------------------------------------------------------
# Arrow Production: I can't wait !
# -------------------------------------------------------------------------------------------------------------------
# Luca Mateo Benitez Garcia: Soooo real!!!
# -------------------------------------------------------------------------------------------------------------------
# greg squad: Thanks you’re the best and was always!!!!!
# -------------------------------------------------------------------------------------------------------------------
# LePorteur 2Lumiere: 💣❤👍
# -------------------------------------------------------------------------------------------------------------------
# Felipe Pernambuco: sparks cara
# -------------------------------------------------------------------------------------------------------------------
# Rilind Vinca: This movie looks cheap! Omg another green lantern movie
# -------------------------------------------------------------------------------------------------------------------
# YoungDre'sBaby: Looks ok I guess.
# -------------------------------------------------------------------------------------------------------------------
# nesh Alexis: 2.0 is best!! Chitti
# -------------------------------------------------------------------------------------------------------------------
# The Lost Jedi: She should have crashed into a Walmart
# -------------------------------------------------------------------------------------------------------------------
# nika nikuradze: wow didn't know this came out
# -------------------------------------------------------------------------------------------------------------------
# hackenely laurent: Not the best trailer marvel has put out
# -------------------------------------------------------------------------------------------------------------------
# i8aGREMLIN: Waiting for the social justice identity politics to ruin the film.
# -------------------------------------------------------------------------------------------------------------------
# Toolness1: Not a great trailer but it's early, I still have hope.  I want this to be awesome!
# -------------------------------------------------------------------------------------------------------------------
# nika nikuradze: i think a saw ronan the deceiver
# -------------------------------------------------------------------------------------------------------------------
# Legend harsh: Why you can't get copyright
# -------------------------------------------------------------------------------------------------------------------
# eastern2western: Palm pilots and Nokia's.
# -------------------------------------------------------------------------------------------------------------------
# Shema Kuppusamy: And Captain Marvel was born
# -------------------------------------------------------------------------------------------------------------------
# This Awesome Channel: Anyone want to be youtube pals and support each others channels ??? Let me know.I LOVE YOU SO DAMN MUCH ❤️❤️
# -------------------------------------------------------------------------------------------------------------------
# Sam Harvey: Nick fury from the past
# -------------------------------------------------------------------------------------------------------------------
# Old Foil: Shazam still better
# -------------------------------------------------------------------------------------------------------------------
# 임주빈: How do people get 4k trailers while the Marvel official YouTube page does not have any 4k trailers? I'm so curious...
# -------------------------------------------------------------------------------------------------------------------
# kiary Dcm: Temprano otra ves
# -------------------------------------------------------------------------------------------------------------------
# Ben Chui: marvel's wonder woman~
# -------------------------------------------------------------------------------------------------------------------
# VV_ Antares: fail to see how this blonde bombshell can take on the almighty thanos..... but.... will see lets just hope that thanos doesn't magically now become shit at fighting
# -------------------------------------------------------------------------------------------------------------------
# aaroney132: Captain Marvel > Wonder Woman
# -------------------------------------------------------------------------------------------------------------------
# 45eno: No one found her acting a bit weak?  No emotion, just uninteresting.
# -------------------------------------------------------------------------------------------------------------------
# Rigor Mortiis: This looks terrible.
# -------------------------------------------------------------------------------------------------------------------
# Coen Conradie: Captain marvel aka the mcu green lantern    looks boring and very very very much sjw garbage.
# -------------------------------------------------------------------------------------------------------------------
# nukelee99: This sucks so bad.
# -------------------------------------------------------------------------------------------------------------------
